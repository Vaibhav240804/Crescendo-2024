# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="yangheng/deberta-v3-base-absa-v1.1")

result = pipe("The screen is good, but the battery life is too short")
print(result)
# Out:
# c:\Users\ditec\anaconda3\envs\crescendo\lib\site-packages\tensorflow\python\framework\dtypes.py:513: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.object,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Use a pipeline as a high-level helper
# ----> 2 from transformers import pipeline
#       4 pipe = pipeline("text-classification", model="yangheng/deberta-v3-base-absa-v1.1")
#       6 result = pipe("The screen is good, but the battery life is too short")
#
# File c:\Users\ditec\anaconda3\envs\crescendo\lib\site-packages\transformers\__init__.py:22
#      18     absl.logging._warn_preinit_stderr = False
#      20 import logging
# ---> 22 from .configuration_albert import ALBERT_PRETRAINED_CONFIG_ARCHIVE_MAP, AlbertConfig
# ...
